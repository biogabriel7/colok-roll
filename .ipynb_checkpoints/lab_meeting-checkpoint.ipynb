# %%
# Morphological background subtraction
corrected, metadata = bg_subtractor.subtract_background(
    image=image_data,
    method='morphological',
    size=20,  # Structuring element size
    shape='disk'  # or 'square'
)

# %%
# Gaussian background subtraction
corrected, metadata = bg_subtractor.subtract_background(
    image=image_data,
    method='gaussian',
    sigma=15.0  # Smoothing parameter
)
